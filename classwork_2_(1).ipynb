# %% [markdown]
# <a href="https://colab.research.google.com/github/Vilars/Data-205/blob/main/classwork_2_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import the python package for handling data frames  Grade: 0.5
import pandas as pd

# %%
# Read the CSV file into a data frame variable df_1 and display the first rows.  Grade: 1
df_1 = pd.read_csv('/content/classwork_2 (1).csv', )

# %%
# What are the data types of the variables? use the method info and the attribute dtypes  Grade: 1
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Y       1460 non-null   int64
#  1   X1      1460 non-null   int64
#  2   X2      1460 non-null   int64
#  3   X3      1460 non-null   int64
#  4   X4      1460 non-null   int64
#  5   X5      1201 non-null   float64
#  6   X6      1460 non-null   object
# dtypes: float64(1), int64(5), object(1)
# memory usage: 80.0+ KB

# %%
# Use a method that gives you the count, mean, std etc of every variable. Grade: 0.5
df_1.describe()
# Out:
#                    Y           X1           X2           X3           X4  \
# count    1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean   180921.195890     6.099315  1515.463699     1.767123  1057.429452
# std     79442.502883     1.382997   525.480383     0.747315   438.705324
# min     34900.000000     1.000000   334.000000     0.000000     0.000000
# 25%    129975.000000     5.000000  1129.500000     1.000000   795.750000
# 50%    163000.000000     6.000000  1464.000000     2.000000   991.500000
# 75%    214000.000000     7.000000  1776.750000     2.000000  1298.250000
# max    755000.000000    10.000000  5642.000000     4.000000  6110.000000
#
#                 X5
# count  1201.000000
# mean     70.049958
# std      24.284752
# min      21.000000
# 25%      59.000000
# 50%      69.000000
# 75%      80.000000
# max     313.000000

# %%
# X6 is a categorical variable. What is the mean value of Y for each category of X6?  Grade: 1.5
df_1.groupby('X6')['Y'].mean()
# Out:
# X6
# COD      143973.255814
# CWD      210600.000000
# Con      269600.000000
# ConLD    138780.888889
# ConLI    200390.000000
# ConLw    143700.000000
# New      274945.418033
# Oth      119850.000000
# WD       173401.836622
# Name: Y, dtype: float64

# %%
# How many Null values does each column has?  Grade: 0.5
df_1.isnull().sum()
# Out:
# Y       0
# X1      0
# X2      0
# X3      0
# X4      0
# X5    259
# X6      0
# dtype: int64

# %%
# Replace the null values of df_1 with the mean of the columns and assign to df_3. Show that df_3 has no null values? Grade: 1.5
df_3 = df_1.fillna(df_1['X5'].mean())
df_3.isnull().sum()
# Out:
# Y     0
# X1    0
# X2    0
# X3    0
# X4    0
# X5    0
# X6    0
# dtype: int64

# %%
# Change the categorical variables of df_1 into dummy variables and assign to df_2. Display the first rows of df_2  Grade: 1
df_2 = pd.get_dummies(df_1)
df_2.head()
# Out:
#         Y  X1    X2  X3    X4    X5  X6_COD  X6_CWD  X6_Con  X6_ConLD  \
# 0  208500   7  1710   2   856  65.0   False   False   False     False
# 1  181500   6  1262   2  1262  80.0   False   False   False     False
# 2  223500   7  1786   2   920  68.0   False   False   False     False
# 3  140000   7  1717   3   756  60.0   False   False   False     False
# 4  250000   8  2198   3  1145  84.0   False   False   False     False
#
#    X6_ConLI  X6_ConLw  X6_New  X6_Oth  X6_WD
# 0     False     False   False   False   True
# 1     False     False   False   False   True
# 2     False     False   False   False   True
# 3     False     False   False   False   True
# 4     False     False   False   False   True

# %%
# Consider X1 as a categorical variable. Plot the relationship of X1 and Y. Hint: use Boxplot.   Grade: 1.5
df_1.boxplot(column='Y', by='X1')
# Out:
# <Axes: title={'center': 'Y'}, xlabel='X1'>

# %%
# Plot the relatioship between X4 and Y. Hint: use scatter plot.   Grade: 1
import matplotlib.pyplot as plt
plt.scatter(df_1['X4'], df_1['Y'])
plt.show()
